# %%
print("Welcome to the Pattern Generator and Number Analyzer!")

while True:
    print("\n--- MENU ---")
    print("1. Pattern Generation")
    print("2. Number Analysis")
    print("3. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        pattern = input("Enter pattern (triangle/pyramid/diamond): ").lower()
        
        rows = int(input("Enter number of rows: "))
        if rows <= 0:
            print("Rows must be positive!")
            continue

        if pattern == "triangle":
            for i in range(1, rows + 1):
                print("*" * i)

        elif pattern == "pyramid":
            for i in range(1, rows + 1):
                print(" " * (rows - i) + "* " * i)

        elif pattern == "diamond":
            for i in range(1, rows + 1):
                print(" " * (rows - i) + "* " * i)
            for i in range(rows - 1, 0, -1):
                print(" " * (rows - i) + "* " * i)

        else:
            print("Invalid pattern!")

    elif choice == "2":
        start = int(input("Enter start: "))
        end = int(input("Enter end: "))

        if end < start:
            print("End must be greater than start!")
            continue

        print("Even numbers:")
        for i in range(start, end + 1):
            if i % 2 == 0:
                print(i, end=" ")

        print("\nOdd numbers:")
        for i in range(start, end + 1):
            if i % 2 != 0:
                print(i, end=" ")

        total = 0
        for i in range(start, end + 1):
            total += i

        print("\nSum =", total)

    elif choice == "3":
        print("Program exited!")
        break

    else:
        print("Invalid choice! Try again.")
# Out:
# Welcome to the Pattern Generator and Number Analyzer!
#
# --- MENU ---
# 1. Pattern Generation
# 2. Number Analysis
# 3. Exit
# Enter your choice:  1
# Enter pattern (triangle/pyramid/diamond):  triangle
# Enter number of rows:  5
# *
# **
# ***
# ****
# *****
#
# --- MENU ---
# 1. Pattern Generation
# 2. Number Analysis
# 3. Exit
# Enter your choice:  1
# Enter pattern (triangle/pyramid/diamond):  diamond
# Enter number of rows:  5
#     *
#    * *
#   * * *
#  * * * *
# * * * * *
#  * * * *
#   * * *
#    * *
#     *
#
# --- MENU ---
# 1. Pattern Generation
# 2. Number Analysis
# 3. Exit
# Enter your choice:  2
# Enter start:  2
# Enter end:  7
# Even numbers:
# 2 4 6
# Odd numbers:
# 3 5 7
# Sum = 27
#
# --- MENU ---
# 1. Pattern Generation
# 2. Number Analysis
# 3. Exit
